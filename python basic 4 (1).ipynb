# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\programdata\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\programdata\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\programdata\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\programdata\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import pandas as pd 
import numpy as np

s = pd.Series() 
print("Pandas Series: ", s) 
data = np.array(['g', 'e', 'e', 'k', 's']) 
  
s = pd.Series(data) 
print("Pandas Series:\n", s)
# Out:
# Pandas Series:  Series([], dtype: object)
# Pandas Series:
#  0    g
# 1    e
# 2    e
# 3    k
# 4    s
# dtype: object

# %%
import pandas as pd 
   
df = pd.DataFrame() 
print(df)
lst = ['Geeks', 'For', 'Geeks', 'is', 'portal', 'for', 'Geeks'] 
  
df = pd.DataFrame(lst) 
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []
#         0
# 0   Geeks
# 1     For
# 2   Geeks
# 3      is
# 4  portal
# 5     for
# 6   Geeks

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\lokesh\Desktop\PDA\data.csv")
print(df.head())
# Out:
#    Unnamed: 0   name  age     city category  sales  a   b
# 0           0   John   25    Delhi        A    200  5  10
# 1           1   Riya   22   Mumbai        B    120  2   3
# 2           2   Aman   30     Pune        A    250  7   8
# 3           3   Neha   27  Kolkata        C    300  4   6
# 4           4  Arjun   35   Jaipur        B    200  1   9

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  13 non-null     int64
#  1   name        10 non-null     object
#  2   age         13 non-null     int64
#  3   city        10 non-null     object
#  4   category    10 non-null     object
#  5   sales       13 non-null     int64
#  6   a           13 non-null     int64
#  7   b           13 non-null     int64
# dtypes: int64(5), object(3)
# memory usage: 964.0+ bytes
# None

# %%
print(df.isnull().sum())
df = df.fillna(0)
# Out:
# Unnamed: 0    0
# name          3
# age           0
# city          3
# category      3
# sales         0
# a             0
# b             0
# dtype: int64

# %%
ages = df[df['age'] > 25]
print(ages)
# Out:
#     Unnamed: 0   name  age       city category  sales  a  b
# 2            2   Aman   30       Pune        A    250  7  8
# 3            3   Neha   27    Kolkata        C    300  4  6
# 4            4  Arjun   35     Jaipur        B    200  1  9
# 5            5    Jay   34  Bangalore        A    100  3  7
# 11          11  Arjun   35          0        B      0  1  9

# %%
df['total'] = df['a'] + df['b']
print(df.head())
# Out:
#    Unnamed: 0   name  age     city category  sales  a   b  total
# 0           0   John   25    Delhi        A    200  5  10     15
# 1           1   Riya   22   Mumbai        B    120  2   3      5
# 2           2   Aman   30     Pune        A    250  7   8     15
# 3           3   Neha   27  Kolkata        C    300  4   6     10
# 4           4  Arjun   35   Jaipur        B    200  1   9     10

# %%
res = df.groupby('category')['sales'].sum()
print(res)
# Out:
# category
# 0    300
# A    650
# B    440
# C    300
# Name: sales, dtype: int64

# %%
import pandas as pd 
s = pd.Series([10, 20, 30, 40])
print(s)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
import pandas as pd
s = pd.Series([85, 90, 78], index=["A", "B", "C"])
print(s)
# Out:
# A    85
# B    90
# C    78
# dtype: int64

# %%
s = pd.Series([10, 20, 30], index=["A", "B", "C"])
print(s[0])     
print(s["A"])   
print(s)
# Out:
# 10
# 10
# A    10
# B    20
# C    30
# dtype: int64
# C:\Users\lokesh\AppData\Local\Temp\ipykernel_27236\1802625928.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(s[0])

# %%
s = pd.Series([10, 20, 30], index=["A", "B", "C"])
s.mean(), s.max(), s.min()
# Out:
# (20.0, 30, 10)

# %%
s = pd.Series([10, 20, 30], index=["A", "B", "C"])
data = { 
"Name": ["Amit", "Riya", "Karan"], 
"Marks": [85, 90, 78] 
} 
df = pd.DataFrame(data)

print(df["Name"])
print(df["Marks"])
print(df.iloc[0])
print(df)
# Out:
# 0     Amit
# 1     Riya
# 2    Karan
# Name: Name, dtype: object
# 0    85
# 1    90
# 2    78
# Name: Marks, dtype: int64
# Name     Amit
# Marks      85
# Name: 0, dtype: object
#     Name  Marks
# 0   Amit     85
# 1   Riya     90
# 2  Karan     78

# %%
s = pd.Series([10, 20, 30], index=["A", "B", "C"])

df["Name"]
print(df["Name"])
# Out:
# 0     Amit
# 1     Riya
# 2    Karan
# Name: Name, dtype: object

# %%
s = pd.Series([10, 20, 30], index=["A", "B", "C"])

df.loc[0] 
df.iloc[1]

print(df.loc[0])
print(df.iloc[1])
# Out:
# Name     Amit
# Marks      85
# Name: 0, dtype: object
# Name     Riya
# Marks      90
# Name: 1, dtype: object

# %%
s = pd.Series([10, 20, 30], index=["A", "B", "C"])

df["Grade"] = ["A", "A+", "B"]
print(df["Grade"])
# Out:
# 0     A
# 1    A+
# 2     B
# Name: Grade, dtype: object

# %%
s = pd.Series([10, 20, 30], index=["A", "B", "C"])

df.drop("Grade", axis=1)
print(df)
# Out:
#     Name  Marks Grade
# 0   Amit     85     A
# 1   Riya     90    A+
# 2  Karan     78     B

# %%
s = pd.Series([10, 20, 30], index=["A", "B", "C"])

df[df["Marks"] > 80]
print(df)
# Out:
#     Name  Marks Grade
# 0   Amit     85     A
# 1   Riya     90    A+
# 2  Karan     78     B

# %%
s = pd.Series([10, 20, 30], index=["A", "B", "C"])

df.describe()
print(df)
# Out:
#     Name  Marks Grade
# 0   Amit     85     A
# 1   Riya     90    A+
# 2  Karan     78     B
